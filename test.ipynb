# %%
from ultralytics import YOLO

# 1. panggil model
# Pastikan path ini benar (cek folder runs/detect/...)
model = YOLO('D:/grinding/project/Otomisasi Pemilahan Sampah Berbasil Visi Komputer/runs/detect/model_sampah_v15/weights/best.pt') 
    
# 2. tes model
# conf=0.25 adalah standar, kalau tidak terdeteksi bisa diturunkan ke 0.15
model.predict(source='D:/grinding/project/Otomisasi Pemilahan Sampah Berbasil Visi Komputer/data test/kayu2.png', conf=0.15, save=True, show=True)
# Out:
# image 1/1 D:\grinding\project\Otomisasi Pemilahan Sampah Berbasil Visi Komputer\data test\kayu2.png: 352x640 1 Organic, 1 Plastic bag, 56.9ms
# Speed: 3.9ms preprocess, 56.9ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to D:\grinding\project\Otomisasi Pemilahan Sampah Berbasil Visi Komputer\runs\detect\predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...
